# %% [markdown]
# <a href="https://colab.research.google.com/github/pavan7479/machine-learning/blob/main/sallary_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.isnull().sum()
# Out:
# experience                    2
# test_score(out of 10)         1
# interview_score(out of 10)    0
# salary($)                     0
# dtype: int64

# %%
import math

df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].median())

# %%
df['test_score(out of 10)']
# Out:
# 0     8.0
# 1     8.0
# 2     6.0
# 3    10.0
# 4     9.0
# 5     7.0
# 6     8.0
# 7     7.0
# Name: test_score(out of 10), dtype: float64

# %%
df.isnull().sum()
# Out:
# experience                    2
# test_score(out of 10)         0
# interview_score(out of 10)    0
# salary($)                     0
# dtype: int64

# %%
# !pip install word2number
from word2number import w2n

# %%
df.experience=df.experience.fillna('zero')
#df.experience=df.experience.astype(str)
#df.experience = df.experience.apply(w2n.word_to_num)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    8.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(df[['experience','test_score(out of 10)','interview_score(out of 10)']],df['salary($)'])
# Out:
# LinearRegression()

# %%
reg.predict([[10,10,10]])
# Out:
# array([86376.27365357])

# %%
plt.scatter(df[['experience']],df['salary($)'])

# %%
reg.score(df[['experience','test_score(out of 10)','interview_score(out of 10)']],df['salary($)'
])
# Out:
# 0.9616780002577959
